# %%
import numpy as np
import pandas as pd
import datetime as dt
import time, random
import warnings

import yfinance as yf
from pandas_datareader import data as pdr
from fredapi import Fred

# ---------- Display prefs ----------
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: f'{x:.6f}')
warnings.filterwarnings("ignore")

# ---------- API key (FRED) ----------
with open(r'C:\Users\brian\api_keys\fred_api_key.txt', 'r') as f:
    fred_api_key = f.read().strip()
fred = Fred(api_key=fred_api_key)

# ---------- Config ----------
START = dt.datetime(2010, 1, 1)
END   = dt.datetime.today()

# Use DBC instead of PDBC so Stooq works; add Gold (GLD) and Silver (SLV)
ASSETS = {
    'Stocks'                : 'ACWI',
    'Bonds'                 : 'AGG',
    'Commercial RealEstate' : 'VNQ',
    'Commodities'           : 'DBC',   # Stooq-friendly broad commodity ETF
    'Residential RealEstate': 'ITB',
    'Gold'                  : 'GLD',
    'Silver'                : 'SLV',
}
# Stooq symbols typically need '.US' suffix
STOOQ = {k: f"{t}.US" for k, t in ASSETS.items()}

# ---------- Backoff ----------
def backoff_sleep(attempt, base=1.5, cap=45):
    delay = min(cap, (base ** attempt)) * (0.7 + 0.6 * random.random())
    time.sleep(delay)

# ---------- Fetch from Stooq (primary) ----------
def fetch_stooq_monthly(symbol, start, end, tries=3):
    last_err = None
    for a in range(tries):
        try:
            df = pdr.DataReader(symbol, "stooq", start, end)  # returns daily, descending index
            if df is None or df.empty or "Close" not in df.columns:
                raise RuntimeError("Empty or missing Close from Stooq")
            # Stooq comes newest->oldest; flip to ascending
            df = df.sort_index()
            s = df["Close"].copy()
            s = s.resample("M").last()
            return s
        except Exception as e:
            last_err = e
            if a < tries - 1:
                backoff_sleep(a+1)
            else:
                raise

# ---------- Fetch from Yahoo (fallback) ----------
def fetch_yahoo_monthly(ticker, start, end, tries=5):
    last_err = None
    for a in range(tries):
        try:
            # monthly interval (few requests) + auto_adjust
            df = yf.download(
                tickers=ticker,
                start=start, end=end,
                interval="1mo",
                auto_adjust=True,
                progress=False,
                group_by="ticker",
                threads=False  # be gentle on rate limits
            )
            if df is None or len(df) == 0:
                raise RuntimeError(f"Empty frame for {ticker}")
            if isinstance(df.columns, pd.MultiIndex):
                # Multi-index when group_by='ticker' even for single ticker
                if (ticker, "Close") in df.columns:
                    s = df[(ticker, "Close")].copy()
                elif "Close" in df[ticker].columns:
                    s = df[ticker]["Close"].copy()
                else:
                    raise RuntimeError(f"No Close col for {ticker}")
            else:
                if "Close" not in df.columns:
                    raise RuntimeError(f"No Close col for {ticker}")
                s = df["Close"].copy()
            s.index = pd.to_datetime(s.index)
            s = s.sort_index()
            return s
        except Exception as e:
            last_err = e
            if a < tries - 1:
                backoff_sleep(a+1)
            else:
                raise

# ---------- Unified fetch: try Stooq first, then Yahoo ----------
def get_monthly_prices(assets, stooq_map, start, end):
    series_list = []
    for name, yftick in assets.items():
        stooq_sym = stooq_map[name]
        s = None
        # 1) Stooq
        try:
            s = fetch_stooq_monthly(stooq_sym, start, end)
        except Exception:
            pass
        # 2) Yahoo fallback
        if s is None or s.empty:
            s = fetch_yahoo_monthly(yftick, start, end)
        # name and append
        s.name = name
        series_list.append(s)
    prices_m = pd.concat(series_list, axis=1)
    return prices_m

# ---------- Download monthly prices (Stooq first) ----------
prices_m = get_monthly_prices(ASSETS, STOOQ, START, END)

print("Monthly price availability (non-NA counts):")
print(prices_m.notna().sum())
print("\nFirst/last non-NA dates per asset:")
for col in prices_m.columns:
    non_na = prices_m[col].dropna()
    if non_na.empty:
        print(f"{col}: EMPTY")
    else:
        print(f"{col}: {non_na.index[0].date()} -> {non_na.index[-1].date()}")

# Drop any all-NA columns
empty_cols = [c for c in prices_m.columns if prices_m[c].dropna().empty]
if empty_cols:
    print(f"\nWARNING: Dropping empty assets: {empty_cols}")
    prices_m = prices_m.drop(columns=empty_cols)

if prices_m.shape[1] < 1:
    raise RuntimeError("No price data available after fetch. Check symbols or connectivity.")

# ---------- Align by common inception ----------
first_valids = prices_m.apply(lambda s: s.first_valid_index())
start_common = max([d for d in first_valids if pd.notna(d)])
prices_m = prices_m.loc[start_common:].dropna(how="any")

if prices_m.shape[0] < 2:
    raise RuntimeError("Not enough overlapping months to compute returns after alignment.")

# ---------- Monthly log returns ----------
logret_etf_m = np.log(prices_m).diff().dropna()

# ---------- Risk-free via FRED: TB3MS -> monthly log returns ----------
tbill = fred.get_series("TB3MS", observation_start=logret_etf_m.index[0], observation_end=END)  # % p.a., monthly
tbill = tbill.to_frame("TB3MS")
tbill.index = pd.to_datetime(tbill.index)
tbill.index = tbill.index.to_period("M").to_timestamp("M")
tbill_m = tbill.asfreq("M")

rf_simple_m = (1.0 + tbill_m["TB3MS"]/100.0) ** (1/12.0) - 1.0
rf_log_m = np.log(1.0 + rf_simple_m)
rf_log_m.name = "Cash_RF_3M_TBill"

# Align to asset return index
rf_log_m = rf_log_m.reindex(logret_etf_m.index).dropna()
common_idx = logret_etf_m.index.intersection(rf_log_m.index)
returns_log_m = pd.concat([logret_etf_m.loc[common_idx], rf_log_m.loc[common_idx]], axis=1).dropna(how="any")

# ---------- Stats ----------
mean_log_monthly = returns_log_m.mean()
cov_log_monthly  = returns_log_m.cov()

mean_log_annual = mean_log_monthly * 12.0
cov_log_annual  = cov_log_monthly * 12.0

var_log_annual = np.diag(cov_log_annual)
arith_mean_annual = np.exp(mean_log_annual + 0.5 * var_log_annual) - 1.0
arith_mean_annual = pd.Series(arith_mean_annual, index=returns_log_m.columns, name="Annual_Arithmetic_Mean")

# ---------- Outputs ----------
print("\nCombined monthly log returns shape:", returns_log_m.shape)
print("Date range:", returns_log_m.index[0].date(), "->", returns_log_m.index[-1].date())

print("\nAssets included (monthly log returns):")
print(list(returns_log_m.columns))

print("\nMonthly log-return means:")
display(mean_log_monthly)

print("\nMonthly log-return covariance matrix:")
display(cov_log_monthly)

print("\nAnnualized log-return means:")
display(mean_log_annual)

print("\nAnnualized log-return covariance matrix:")
display(cov_log_annual)

print("\nApproximate Annual Arithmetic Means (from annual log mean & variance):")
display(arith_mean_annual)

print("\nMonthly correlation matrix:")
display(returns_log_m.corr())
# Out:
# Monthly price availability (non-NA counts):
# Stocks                    189
# Bonds                     189
# Commercial RealEstate     189
# Commodities               189
# Residential RealEstate    189
# Gold                      189
# Silver                    189
# dtype: int64
#
# First/last non-NA dates per asset:
# Stocks: 2010-01-31 -> 2025-09-30
# Bonds: 2010-01-31 -> 2025-09-30
# Commercial RealEstate: 2010-01-31 -> 2025-09-30
# Commodities: 2010-01-31 -> 2025-09-30
# Residential RealEstate: 2010-01-31 -> 2025-09-30
# Gold: 2010-01-31 -> 2025-09-30
# Silver: 2010-01-31 -> 2025-09-30
#
# Combined monthly log returns shape: (187, 8)
# Date range: 2010-02-28 -> 2025-08-31
#
# Assets included (monthly log returns):
# ['Stocks', 'Bonds', 'Commercial RealEstate', 'Commodities', 'Residential RealEstate', 'Gold', 'Silver', 'Cash_RF_3M_TBill']
#
# Monthly log-return means:
# Stocks                   0.007983
# Bonds                    0.001079
# Commercial RealEstate    0.006610
# ...

# %%
# ===== Inputs from previous script =====
# - returns_log_m: monthly log returns DataFrame (cols = assets incl. 'Cash_RF_3M_TBill')
# - arith_mean_annual: Series of annualized arithmetic means for each column in returns_log_m
# - cov_log_annual: DataFrame of annualized covariance (log-return based, acceptable for risk)

# ----- Build investable universe and risk-free -----
ALL_ASSETS = list(returns_log_m.columns)
RF_NAME = 'Cash_RF_3M_TBill'
if RF_NAME not in ALL_ASSETS:
    raise ValueError(f"Expected '{RF_NAME}' in returns_log_m columns.")

# Exclude cash from the risky asset set (we'll use it as rf in Sharpe)
ASSETS = [a for a in ALL_ASSETS if a != RF_NAME]

mean_returns = arith_mean_annual.loc[ASSETS].values            # annualized arithmetic means
cov_matrix   = cov_log_annual.loc[ASSETS, ASSETS].values       # annualized covariance
rf_annual    = float(arith_mean_annual.loc[RF_NAME])           # annualized arithmetic rf

asset_names = ASSETS
num_assets = len(asset_names)

# ===== Portfolio Simulation =====
def simulate_portfolios(mean_returns, cov_matrix, rf, num_portfolios=10000, seed=None):
    """
    Monte Carlo over long-only fully-invested weights.
    Returns a DataFrame with weights, expected return, risk (stdev), and Sharpe.
    """
    if seed is not None:
        np.random.seed(seed)

    # Sample weights from a Dirichlet (sums to 1, long-only)
    weights = np.random.dirichlet(alpha=np.ones(num_assets), size=num_portfolios)  # (N, A)

    # Expected annual return for each portfolio (arithmetic means)
    port_ret = weights @ mean_returns  # (N,)

    # Portfolio variance via quadratic form: diag(W * C * W^T)
    # Efficient computation using einsum:
    port_var = np.einsum('ij,jk,ik->i', weights, cov_matrix, weights)  # (N,)
    port_std = np.sqrt(np.maximum(port_var, 0.0))

    # Sharpe vs risk-free
    excess = port_ret - rf
    sharpe = np.divide(excess, port_std, out=np.full_like(excess, np.nan), where=port_std > 0)

    # Assemble results
    cols = [f'w_{n}' for n in asset_names] + ['exp_return', 'exp_risk', 'sharpe']
    res = np.column_stack([weights, port_ret, port_std, sharpe])
    return pd.DataFrame(res, columns=cols)

# Run the simulation
num_portfolios = 10000
results_df = simulate_portfolios(mean_returns, cov_matrix, rf_annual, num_portfolios=num_portfolios, seed=42)


# ===== Optional screening & selection =====
# Example: filter by minimum expected return (annual, arithmetic)
min_return = 0.15   # 15% floor; adjust as desired
filtered = results_df.loc[results_df['exp_return'] >= min_return].copy()
if filtered.empty:
    # If too strict, fall back to all
    filtered = results_df

# Pick the max-Sharpe portfolio from the filtered set
best_idx = filtered['sharpe'].idxmax()
best_portfolio = filtered.loc[best_idx]

# ===== Pretty print =====
def print_portfolio(asset_names, row, time_horizon_years=5):
    print("Optimal Portfolio Allocation (Max Sharpe):")
    for name, w in zip(asset_names, row[[f'w_{n}' for n in asset_names]].values):
        print(f"  {name:24s}: {100*w:6.2f}%")

    exp_ret = float(row['exp_return'])  # annual arithmetic
    exp_std = float(row['exp_risk'])    # annual stdev
    sharpe  = float(row['sharpe'])

    # Multi-year compounding on expected return (simple projection)
    T = time_horizon_years
    exp_multiyear = (1 + exp_ret)**T - 1

    print(f"\nAssumed risk-free (3M T-Bill): {rf_annual:6.2%}")
    print(f"Expected Annual Return      : {exp_ret:6.2%}")
    print(f"Expected Annual Risk (Stdev): {exp_std:6.2%}")
    print(f"Sharpe (excess over rf)     : {sharpe:6.3f}")
    print(f"{T}-Year Compounded Return  : {exp_multiyear:6.2%}")

print_portfolio(asset_names, best_portfolio, time_horizon_years=5)
# Out:
# Optimal Portfolio Allocation (Max Sharpe):
#   Stocks                  :  10.94%
#   Bonds                   :   3.69%
#   Commercial RealEstate   :   1.17%
#   Commodities             :   4.91%
#   Residential RealEstate  :  59.54%
#   Gold                    :  18.53%
#   Silver                  :   1.22%
#
# Assumed risk-free (3M T-Bill):  1.33%
# Expected Annual Return      : 15.17%
# Expected Annual Risk (Stdev): 18.98%
# Sharpe (excess over rf)     :  0.729
# 5-Year Compounded Return  : 102.65%

# %%
frontier = results_df[['exp_risk', 'exp_return']]
frontier.sort_values(by=["exp_return"],ascending=False)
# Out:
#       exp_risk  exp_return
# 9500  0.242978    0.179110
# 2751  0.240203    0.175352
# 3394  0.232310    0.173392
# 1114  0.227275    0.171427
# 3059  0.223392    0.170472
# 8493  0.228561    0.168476
# 7608  0.218288    0.163642
# 2138  0.218864    0.163087
# 5510  0.211046    0.161287
# 9124  0.210393    0.160870
# 2688  0.210141    0.160648
# 6032  0.213906    0.160129
# 2287  0.214117    0.160110
# 9738  0.210339    0.159438
# 6589  0.202402    0.159368
# 6173  0.214998    0.158690
# 9684  0.205454    0.157726
# 326   0.205945    0.157524
# 1077  0.215859    0.157244
# 1123  0.210514    0.156893
# 8852  0.209124    0.156389
# 5363  0.204017    0.156147
# 9608  0.209510    0.156094
# 3722  0.206154    0.155751
# 6451  0.204694    0.155636
# 2918  0.196159    0.155370
# 2781  0.205134    0.155314
# 3832  0.204752    0.154822
# 8509  0.206466    0.154717
# 8856  0.197422    0.154616
# 6110  0.200850    0.154527
# 3440  0.202211    0.154073
# 3893  0.197400    0.153376
# ...

# %%
# ---- Efficient Frontier Plot (Plotly) ----
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

cloud = results_df.copy()

# Identify special portfolios
min_var_idx = cloud['exp_risk'].idxmin()
min_var_pt  = cloud.loc[min_var_idx]
tangency_pt = best_portfolio  # from your previous selection

# Prepare customdata with weights (same order as asset_names)
weight_cols = [f"w_{n}" for n in asset_names]
customdata = cloud[weight_cols].values  # shape (N, A)

# Base scatter of all portfolios
fig = px.scatter(
    cloud,
    x='exp_risk',
    y='exp_return',
    color='sharpe',
    color_continuous_scale='Viridis',
    hover_data={'sharpe': ':.3f'},  # these columns exist in `cloud`
    labels={'exp_risk': 'Annual Risk (σ)', 'exp_return': 'Expected Return (annual)', 'sharpe': 'Sharpe'},
    title='Efficient Frontier (Monte Carlo) – Risk vs Return'
)

# Attach customdata and a custom hovertemplate that shows weights nicely
weight_lines = "".join([f"{name}: %{{customdata[{i}]:.2%}}<br>" for i, name in enumerate(asset_names)])
fig.update_traces(
    customdata=customdata,
    hovertemplate=(
        "σ: %{x:.2%}<br>"
        "Return: %{y:.2%}<br>"
        "Sharpe: %{marker.color:.3f}<br>"  # color is sharpe
        + weight_lines +
        "<extra></extra>"
    )
)

# Add Max-Sharpe (Tangency) and Min-Variance markers
fig.add_trace(go.Scatter(
    x=[tangency_pt['exp_risk']], y=[tangency_pt['exp_return']],
    mode='markers',
    marker=dict(size=14, symbol='star', color='crimson'),
    name='Max Sharpe (Tangency)',
    hovertemplate=(
        "<b>Max Sharpe (Tangency)</b><br>"
        f"Sharpe: {tangency_pt['sharpe']:.3f}<br>"
        f"σ: {tangency_pt['exp_risk']:.2%}<br>"
        f"Return: {tangency_pt['exp_return']:.2%}<extra></extra>"
    )
))
fig.add_trace(go.Scatter(
    x=[min_var_pt['exp_risk']], y=[min_var_pt['exp_return']],
    mode='markers',
    marker=dict(size=12, symbol='diamond', color='orange'),
    name='Min Variance',
    hovertemplate=(
        "<b>Min Variance</b><br>"
        f"σ: {min_var_pt['exp_risk']:.2%}<br>"
        f"Return: {min_var_pt['exp_return']:.2%}<extra></extra>"
    )
))

# Capital Market Line (CML): y = rf + slope * x through tangency
slope = (float(tangency_pt['exp_return']) - rf_annual) / float(tangency_pt['exp_risk']) if tangency_pt['exp_risk'] > 0 else 0.0
x_max = float(cloud['exp_risk'].max()) * 1.05
x_cml = np.linspace(0.0, x_max, 100)
y_cml = rf_annual + slope * x_cml

fig.add_trace(go.Scatter(
    x=x_cml, y=y_cml,
    mode='lines',
    line=dict(color='red', width=2, dash='dash'),
    name='Capital Market Line'
))

# Risk-free point at σ=0
fig.add_trace(go.Scatter(
    x=[0], y=[rf_annual],
    mode='markers+text',
    marker=dict(size=10, color='red'),
    text=['Risk-Free (3M T-Bill)'],
    textposition='bottom right',
    name='Risk-Free'
))

fig.update_layout(
    xaxis=dict(tickformat='.0%', title='Annual Risk (σ)'),
    yaxis=dict(tickformat='.0%', title='Expected Annual Return'),
    coloraxis_colorbar=dict(title='Sharpe'),
    legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1)
)

fig.show()

# ---- Bar Chart: Max-Sharpe Portfolio Weights ----
import plotly.graph_objects as go
best_weights = tangency_pt[[f"w_{n}" for n in asset_names]].values  # fractions 0..1

fig_w = go.Figure(go.Bar(
    x=asset_names,
    y=best_weights,                       
    text=[f"{w:.2%}" for w in best_weights],
    textposition='outside'
))
fig_w.update_layout(
    title="Max-Sharpe Portfolio Weights",
    yaxis_title="Weight",
    yaxis_tickformat=".0%",                # <-- Plotly will show as %
    xaxis_title="Asset"
)
fig_w.show()
